# %%
import re

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
books_df = pd.read_csv("Data_books/all_books.csv")
books_df.head(15)
# Out:
#                                         book_id_title   book_id  \
# 0                                12042357-think-stats  12042357
# 1                       13162988-information-graphics  13162988
# 2                         13705587-the-functional-art  13705587
# 3                   14744694-python-for-data-analysis  14744694
# 4         148009.The_Elements_of_Statistical_Learning    148009
# 5                                   15815598-big-data  15815598
# 6    17397466-an-introduction-to-statistical-learning  17397466
# 7                  17912916-data-science-for-business  17912916
# 8                           17986418-naked-statistics  17986418
# 9              18774683-practical-data-science-with-r  18774683
# 10                        20344187-thinking-with-data  20344187
# 11               21558327.Introduction_to_probability  21558327
# 12       22263956-data-science-and-big-data-analytics  22263956
# 13     23463279-designing-data-intensive-applications  23463279
# 14  24346909.Introduction_to_machine_learning_with...  24346909
#
#                                            book_title book_series  \
# 0                                         Think Stats         NaN
# 1                                Information Graphics         NaN
# 2   The Functional Art: An Introduction to Informa...         NaN
# 3                            Python for Data Analysis         NaN
# 4   The Elements of Statistical Learning: Data Min...         NaN
# 5   Big Data: A Revolution That Will Transform How...         NaN
# 6   An Introduction to Statistical Learning: With ...         NaN
# 7   Data Science for Business: What you need to kn...         NaN
# 8   Naked Statistics: Stripping the Dread from the...       Naked
# 9                       Practical Data Science with R         NaN
# 10                                 Thinking with Data         NaN
# 11                        Introduction to Probability         NaN
# 12  Data Science and Big Data Analytics: Discoveri...         NaN
# 13              Designing Data-Intensive Applications         NaN
# 14  Introduction to Machine Learning with Python: ...         NaN
#
#          book_series_uri                               top_5_other_editions  \
# 0                    NaN  ['https://www.goodreads.com/book/show/23926969...
# 1                    NaN  ['https://www.goodreads.com/book/show/50981830...
# 2                    NaN  ['https://www.goodreads.com/book/show/19259351...
# 3                    NaN  ['https://www.goodreads.com/book/show/36313494...
# 4                    NaN  ['https://www.goodreads.com/book/show/4094864-...
# 5                    NaN  ['https://www.goodreads.com/book/show/18663148...
# 6                    NaN  ['https://www.goodreads.com/book/show/18925719...
# 7                    NaN  ['https://www.goodreads.com/book/show/18711043...
# 8   /series/177193-naked  ['https://www.goodreads.com/book/show/13707560...
# 9                    NaN  ['https://www.goodreads.com/book/show/49015677...
# 10                   NaN  ['https://www.goodreads.com/book/show/20650938...
# 11                   NaN  ['https://www.goodreads.com/book/show/41861398...
# 12                   NaN  ['https://www.goodreads.com/book/show/24654197...
# 13                   NaN  ['https://www.goodreads.com/book/show/34626431...
# 14                   NaN  ['https://www.goodreads.com/book/show/32317230...
#
#           isbn         isbn13  year_first_published  \
# 0   1491907339  9781491907337                2011.0
# 1   3836583836  9783836583831                2011.0
# 2   0133041360  9780133041361                2011.0
# 3   9352136411  9781491957660                2011.0
# 4   0387848576  9780387848570                2001.0
# 5   0544227751  9780544227750                   NaN
# 6   1071614177  9781461471387                2013.0
# 7   8576089726  9786177730032                2013.0
# 8   0393071952  9780393071955                2012.0
# 9   1617295876  9781617295874                   NaN
# 10  1491949775  9781491949771                2014.0
# 11  1138369918  9781138369917                2014.0
# 12  8126556536  9788126556533                2014.0
# 13  1449373321  9781449373320                2015.0
# 14  1449369898  9781449369897                2015.0
#
#                                            authorlink  \
# 0   https://www.goodreads.com/author/show/5725109....
# 1   https://www.goodreads.com/author/show/5368288....
# 2   https://www.goodreads.com/author/show/5084007....
# 3   https://www.goodreads.com/author/show/6007417....
# 4   https://www.goodreads.com/author/show/1741108....
# 5   https://www.goodreads.com/author/show/5544319....
# 6   https://www.goodreads.com/author/show/461456.G...
# 7   https://www.goodreads.com/author/show/891152.F...
# 8   https://www.goodreads.com/author/show/18704.Ch...
# 9   https://www.goodreads.com/author/show/7382005....
# 10  https://www.goodreads.com/author/show/7710091....
# 11  https://www.goodreads.com/author/show/12243243...
# 12  https://www.goodreads.com/author/show/13150306...
# 13  https://www.goodreads.com/author/show/7969625....
# 14  https://www.goodreads.com/author/show/15901223...
#
#                       author  num_pages  \
# 0            Allen B. Downey      138.0
# 1             Sandra Rendgen      480.0
# 2              Alberto Cairo      384.0
# 3               Wes McKinney      400.0
# 4              Trevor Hastie      533.0
# 5   Viktor Mayer-Schönberger      242.0
# 6               Gareth James      426.0
# 7             Foster Provost      414.0
# 8            Charles Wheelan      304.0
# 9                 Nina Zumel      416.0
# 10                 Max Shron       94.0
# 11      Joseph K. Blitzstein      596.0
# 12    EMC Education Services      432.0
# 13          Martin Kleppmann      562.0
# 14         Andreas C. Müller      400.0
#
#                                                genres  \
# 0   ['Computer Science > Programming', 'Science > ...
# 1   ['Design', 'Nonfiction', 'Art', 'Art > Art Des...
# 2   ['Design', 'Nonfiction', 'Business', 'Art', 'S...
# 3   ['Computer Science > Programming', 'Science > ...
# 4   ['Science > Mathematics', 'Science > Computer ...
# 5   ['Nonfiction', 'Business', 'Science > Technolo...
# 6   ['Science > Computer Science', 'Science > Math...
# 7   ['Business', 'Nonfiction', 'Science > Technolo...
# 8   ['Nonfiction', 'Science', 'Business', 'Science...
# 9   ['Science > Computer Science', 'Computer Scien...
# 10  ['Nonfiction', 'Business', 'Computer Science >...
# 11  ['Science > Mathematics', 'Science', 'Textbook...
# 12  ['Science > Computer Science', 'Business', 'No...
# 13  ['Computer Science > Programming', 'Science > ...
# 14  ['Computer Science > Programming', 'Science > ...
#
#                                               shelves  \
# 0   {'to-read': 719, 'currently-reading': 261, 'da...
# 1   {'to-read': 1048, 'design': 57, 'currently-rea...
# 2   {'to-read': 2566, 'currently-reading': 146, 'd...
# 3   {'to-read': 4825, 'currently-reading': 1280, '...
# 4   {'to-read': 6508, 'currently-reading': 563, 'd...
# 5   {'to-read': 13039, 'currently-reading': 1155, ...
# 6   {'to-read': 5013, 'currently-reading': 713, 'd...
# 7   {'to-read': 8349, 'currently-reading': 1676, '...
# 8   {'to-read': 20181, 'currently-reading': 3172, ...
# 9   {'to-read': 359, 'data-science': 36, 'currentl...
# 10  {'to-read': 361, 'currently-reading': 53, 'dat...
# 11  {'to-read': 529, 'currently-reading': 34, 'mat...
# 12  {'to-read': 209, 'currently-reading': 40, 'dat...
# 13  {'to-read': 16067, 'currently-reading': 6810, ...
# 14  {'to-read': 1783, 'currently-reading': 390, 'd...
#
#                                                 lists  num_ratings  \
# 0   {'Mathematics': 9, 'Humble': 4, 'Statistics': ...          449
# 1   {'The': 4, 'Best': 335, 'Para': 2, 'Visualizat...          327
# 2   {'Data': 2, 'Visualization': 7, 'UX': 138, 'LD...          745
# 3   {'Best': 49, 'Humble': 4, 'Computer': 13, 'pyt...         2040
# 4   {'Data': 116, 'Machine': 82, 'Best': 96, 'Comp...         1681
# 5   {'Best': 1408, 'Open': 14, 'Scary': 61, 'Big':...         8364
# 6   {'Undergraduate': 35, 'Mathematics': 28, 'Comp...         1965
# 7   {'Data': 116, 'Computer': 80, 'Information,': ...         2120
# 8   {'Data': 4, 'Scary': 61, 'Probability': 4, 'On...        12696
# 9                        {'Singularity': 16, 'R': 12}           94
# 10                                                 {}          174
# 11  {'Probability': 4, 'A': 2, 'University': 6, 'T...          118
# 12                                                 {}           58
# 13  {'Required': 82, 'Computer': 32, 'Best': 4, 'E...         6501
# 14  {'Humble': 3, 'Getting': 10, "O'Reilly": 3, 'H...          468
#
#     num_reviews  average_rating  \
# 0            50            3.61
# 1            24            4.39
# 2            48            4.18
# 3           150            4.15
# 4            57            4.42
# 5           714            3.68
# 6           161            4.60
# 7           148            4.15
# 8          1184            3.95
# 9             6            4.15
# 10           25            3.47
# 11           15            4.56
# 12            3            3.84
# 13          637            4.72
# 14           46            4.35
#
#                                   rating_distribution
# 0   {'5 Stars': 84, '4 Stars': 176, '3 Stars': 131...
# 1   {'5 Stars': 177, '4 Stars': 106, '3 Stars': 41...
# 2   {'5 Stars': 291, '4 Stars': 319, '3 Stars': 11...
# 3   {'5 Stars': 798, '4 Stars': 843, '3 Stars': 32...
# 4   {'5 Stars': 992, '4 Stars': 467, '3 Stars': 16...
# 5   {'5 Stars': 1844, '4 Stars': 3141, '3 Stars': ...
# 6   {'5 Stars': 1339, '4 Stars': 499, '3 Stars': 9...
# 7   {'5 Stars': 853, '4 Stars': 840, '3 Stars': 33...
# 8   {'5 Stars': 3628, '4 Stars': 5555, '3 Stars': ...
# 9   {'5 Stars': 40, '4 Stars': 33, '3 Stars': 17, ...
# 10  {'5 Stars': 26, '4 Stars': 63, '3 Stars': 55, ...
# 11  {'5 Stars': 84, '4 Stars': 20, '3 Stars': 10, ...
# 12  {'5 Stars': 12, '4 Stars': 32, '3 Stars': 9, '...
# 13  {'5 Stars': 5005, '4 Stars': 1222, '3 Stars': ...
# 14  {'5 Stars': 237, '4 Stars': 178, '3 Stars': 39...

# %%
plt.figure(figsize=(8,4))
ax = sns.countplot(books_df, x= "year_first_published")
ax.bar_label(ax.containers[0])
ax.axes.set_title("The number of books published in year",fontsize=9)
ax.set_xlabel("First year published",fontsize=9)
plt.show()

# %%
plt.figure(figsize=(8,4))
ax = sns.scatterplot(books_df, x='average_rating', y = 'num_pages')
ax.axes.set_title("The correlation between average rating and number of book's pages",fontsize=9)
ax.set_xlabel("Average Rating",fontsize=9)
ax.set_ylabel("Number of pages",fontsize=9)
plt.show()
